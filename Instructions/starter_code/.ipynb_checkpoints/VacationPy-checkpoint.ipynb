# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
data = pd.read_csv("cities.csv")

data
# Out:
#               city    lat     lng   temp  humidity  cloudiness  windspeed  \
# 0           Barrow  71.29 -156.79  35.60        74          90      17.22
# 1    Srednekolymsk  67.45  153.68  39.45        92         100       2.55
# 2         Svetlaya  46.54  138.33  55.51        82          83       6.82
# 3             Bako   5.78   36.57  70.29        60          71       2.26
# 4    Sioux Lookout  50.10  -91.92  71.60        49          40       6.93
# ..             ...    ...     ...    ...       ...         ...        ...
# 575    Xaltianguis  17.07  -99.83  87.80        70           5       8.05
# 576      Road Town  18.42  -64.62  83.34        87         100       1.01
# 577     Mason City  43.15  -93.20  80.55        42           1       9.17
# 578     San Carlos   9.66  -68.58  85.86        70          91       1.83
# 579  Santa Rosalía  27.32 -112.28  90.07        51           0      10.49
#
#     country        date
# 0        US  1600807802
# 1        RU  1600807837
# 2        RU  1600808005
# 3        ET  1600808005
# 4        CA  1600807787
# ..      ...         ...
# 575      MX  1600808128
# 576      VG  1600808129
# 577      US  1600808129
# 578      VE  1600808129
# 579      MX  1600808015
#
# [580 rows x 9 columns]

# %%
# A max temperature lower than 80 degrees but higher than 70
# Wind speed less than 10 mph
# Zero cloudiness
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal
# Note: Feel free to adjust to your specifications but be sure to limit the number of 
#      rows returned by your API requests to a reasonable number.

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
locations = data[["lat", "lng"]]
humi = data["humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2)
humi_layer = gmaps.heatmap_layer(locations, weights=humi)
fig.add_layer(humi_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hotel_df = data.loc[(data["temp"] <= 80) & (data["windspeed"] <=10) & (data["cloudiness"] == 0)]
hotel_df
# Out:
#                 city    lat     lng   temp  humidity  cloudiness  windspeed  \
# 20             Yumen  40.28   97.20  49.96        47           0       1.99
# 23       Port Alfred -33.59   26.89  58.23        75           0       5.75
# 35      Port Hedland -20.32  118.57  66.20        24           0       6.93
# 42           Noshiro  40.20  140.02  61.66        80           0       8.72
# 54    Port Macquarie -31.43  152.92  52.45        97           0       1.57
# ..               ...    ...     ...    ...       ...         ...        ...
# 527           Tupiza -21.45  -65.72  67.28        19           0       7.85
# 550      Broken Hill -31.95  141.43  50.00        71           0       8.05
# 552            Sevsk  52.15   34.49  54.27        70           0       6.62
# 553  Plettenberg Bay -34.05   23.37  55.67        69           0       5.03
# 558           Narsaq  60.92  -46.05  41.00        35           0       3.36
#
#     country        date
# 20       CN  1600807841
# 23       ZA  1600808009
# 35       AU  1600807843
# 42       JP  1600808012
# 54       AU  1600807879
# ..      ...         ...
# 527      BO  1600808117
# 550      AU  1600808124
# 552      RU  1600808124
# 553      ZA  1600808124
# 558      GL  1600808125
#
# [61 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel_Name'] = ""
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
 # find the closest hotel of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
}

# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():

    # get loc from df
    lat = row['lat']
    lng = row['lng']

    # get loc for each row
    params['location'] = f"{lat},{lng}"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {row['city']}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest {row['city']} hotel is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel_Name'] = results[0]['name']

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 20: Yumen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 23: Port Alfred.
# Closest Port Alfred hotel is The Halyards Hotel.
# ------------
# Retrieving Results for Index 35: Port Hedland.
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Port Hedland hotel is The Esplanade Hotel.
# ------------
# Retrieving Results for Index 42: Noshiro.
# Closest Noshiro hotel is Azuma Ryokan.
# ------------
# Retrieving Results for Index 54: Port Macquarie.
# Closest Port Macquarie hotel is Rydges Port Macquarie.
# ------------
# Retrieving Results for Index 60: Udachny.
# Closest Udachny hotel is Severnoye Siyaniye.
# ------------
# Retrieving Results for Index 61: Nyurba.
# Closest Nyurba hotel is Gostinitsa Alrosa.
# ------------
# Retrieving Results for Index 64: Carnarvon.
# Closest Carnarvon hotel is Hospitality Carnarvon.
# ------------
# Retrieving Results for Index 80: Włoszczowa.
# Closest Włoszczowa hotel is Hotel Mariage.
# ------------
# Retrieving Results for Index 90: Albany.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 97: Airai.
# Closest Airai hotel is Juvinal Martin.
# ------------
# Retrieving Results for Index 107: General Roca.
# Closest General Roca hotel is Hotel El Recreo.
# ------------
# Retrieving Results for Index 111: Port Elizabeth.
# Closest Port Elizabeth hotel is 39 On Nile Guest House.
# ------------
# Retrieving Results for Index 114: Richards Bay.
# Closest Richards Bay hotel is BON Hotel Waterfront Richards Bay.
# ------------
# Retrieving Results for Index 124: Aldan.
# Closest Aldan hotel is Aldan Guest House.
# ------------
# Retrieving Results for Index 127: Lüderitz.
# Closest Lüderitz hotel is LÜDERITZ NEST HOTEL.
# ------------
# Retrieving Results for Index 129: Hofn.
# Closest Hofn hotel is Hótel Höfn.
# ------------
# Retrieving Results for Index 142: Baijiantan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 153: Malbork.
# Closest Malbork hotel is Hotel Centrum Malbork.
# ------------
# Retrieving Results for Index 159: Maningrida.
# Closest Maningrida hotel is Dhukurrdji Lodge.
# ------------
# Retrieving Results for Index 180: Egvekinot.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 182: Presidencia Roque Sáenz Peña.
# Closest Presidencia Roque Sáenz Peña hotel is Hotel Aconcagua.
# ------------
# Retrieving Results for Index 189: Baghlan.
# Closest Baghlan hotel is Habibullah MOsazai.
# ------------
# Retrieving Results for Index 202: Verkhnevilyuysk.
# Closest Verkhnevilyuysk hotel is Gostinitsa Mila.
# ------------
# Retrieving Results for Index 207: Vanavara.
# Closest Vanavara hotel is Russia.
# ------------
# Retrieving Results for Index 212: Qaanaaq.
# Closest Qaanaaq hotel is Qaanaaq Hotel.
# ------------
# Retrieving Results for Index 225: Ust-Maya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 226: Lębork.
# Closest Lębork hotel is Vega.
# ------------
# Retrieving Results for Index 232: Bloemfontein.
# Closest Bloemfontein hotel is Protea Hotel by Marriott Bloemfontein.
# ------------
# Retrieving Results for Index 237: Chernyshevskiy.
# Closest Chernyshevskiy hotel is Chernyseyskiy.
# ------------
# Retrieving Results for Index 246: Churapcha.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 266: Pingliang.
# Closest Pingliang hotel is Xinxiang Hostel.
# ------------
# Retrieving Results for Index 274: Yangi Marg`ilon.
# Closest Yangi Marg`ilon hotel is Ikathouse.
# ------------
# Retrieving Results for Index 282: Saldanha.
# Closest Saldanha hotel is Blue Bay Lodge.
# ------------
# Retrieving Results for Index 284: Kruisfontein.
# Closest Kruisfontein hotel is Oyster Bay House Rental.
# ------------
# Retrieving Results for Index 320: Olovyannaya.
# Closest Olovyannaya hotel is Gostinitsa.
# ------------
# Retrieving Results for Index 324: Agronom.
# Closest Agronom hotel is База Отдыха Дубрава.
# ------------
# Retrieving Results for Index 326: Geraldton.
# Closest Geraldton hotel is Broadwater Mariner Resort.
# ------------
# Retrieving Results for Index 342: Rosário do Sul.
# Closest Rosário do Sul hotel is Hotel Areias Brancas.
# ------------
# Retrieving Results for Index 354: Kumul.
# Closest Kumul hotel is Laoyutang Resort.
# ------------
# Retrieving Results for Index 361: Flinders.
# Closest Flinders hotel is Shellharbour Resort & Conference Centre.
# ------------
# Retrieving Results for Index 369: Ekuvukeni.
# Closest Ekuvukeni hotel is Sibeko Resident.
# ------------
# Retrieving Results for Index 371: Korla.
# Closest Korla hotel is Gulisitan Hotel.
# ------------
# Retrieving Results for Index 375: Batemans Bay.
# Closest Batemans Bay hotel is Batemans Bay Marina Resort.
# ------------
# Retrieving Results for Index 391: Mahuta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 395: Omsukchan.
# Closest Omsukchan hotel is Zori.
# ------------
# Retrieving Results for Index 397: Nogliki.
# Closest Nogliki hotel is Hotel "Nogliki".
# ------------
# Retrieving Results for Index 403: Yulara.
# Closest Yulara hotel is Desert Gardens Hotel - Ayers Rock Resort.
# ------------
# Retrieving Results for Index 451: Boende.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 465: Boysun.
# Closest Boysun hotel is Gaza Hotel.
# ------------
# Retrieving Results for Index 474: Qaqortoq.
# Closest Qaqortoq hotel is Hotel Qaqortoq.
# ------------
# Retrieving Results for Index 477: Sivas Province.
# Closest Sivas Province hotel is Sivas Sultan Otel.
# ------------
# Retrieving Results for Index 490: Kütahya.
# Closest Kütahya hotel is Grand Çınar Hotel.
# ------------
# Retrieving Results for Index 500: Aykhal.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 504: Forsytheganj.
# Closest Forsytheganj hotel is Hotel Svetlogorsk JBIK.
# ------------
# Retrieving Results for Index 524: Okhotsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 527: Tupiza.
# Closest Tupiza hotel is La Torre Hotel.
# ------------
# Retrieving Results for Index 550: Broken Hill.
# Closest Broken Hill hotel is Daydream Motel & Cottages.
# ------------
# Retrieving Results for Index 552: Sevsk.
# Closest Sevsk hotel is Skarabey.
# ------------
# Retrieving Results for Index 553: Plettenberg Bay.
# Closest Plettenberg Bay hotel is Thanda Vista B&B.
# ------------
# Retrieving Results for Index 558: Narsaq.
# Closest Narsaq hotel is Hotel Narsaq.
# ------------

# %%
hotel_df
# Out:
#                 city    lat     lng   temp  humidity  cloudiness  windspeed  \
# 20             Yumen  40.28   97.20  49.96        47           0       1.99
# 23       Port Alfred -33.59   26.89  58.23        75           0       5.75
# 35      Port Hedland -20.32  118.57  66.20        24           0       6.93
# 42           Noshiro  40.20  140.02  61.66        80           0       8.72
# 54    Port Macquarie -31.43  152.92  52.45        97           0       1.57
# ..               ...    ...     ...    ...       ...         ...        ...
# 527           Tupiza -21.45  -65.72  67.28        19           0       7.85
# 550      Broken Hill -31.95  141.43  50.00        71           0       8.05
# 552            Sevsk  52.15   34.49  54.27        70           0       6.62
# 553  Plettenberg Bay -34.05   23.37  55.67        69           0       5.03
# 558           Narsaq  60.92  -46.05  41.00        35           0       3.36
#
#     country        date                 Hotel_Name
# 20       CN  1600807841
# 23       ZA  1600808009         The Halyards Hotel
# 35       AU  1600807843        The Esplanade Hotel
# 42       JP  1600808012               Azuma Ryokan
# 54       AU  1600807879      Rydges Port Macquarie
# ..      ...         ...                        ...
# 527      BO  1600808117             La Torre Hotel
# 550      AU  1600808124  Daydream Motel & Cottages
# 552      RU  1600808124                   Skarabey
# 553      ZA  1600808124           Thanda Vista B&B
# 558      GL  1600808125               Hotel Narsaq
#
# [61 rows x 10 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel_Name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["lat", "lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
